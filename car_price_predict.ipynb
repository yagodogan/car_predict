# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame=pd.read_excel('merc.xlsx')

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.histplot(dataFrame["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
newDataFrame=dataFrame.drop('transmission',axis=1)

# %%
newDataFrame.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
newDataFrame.corr()["price"].sort_values()
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
newDataFrame=pd.DataFrame(newDataFrame)

# %%
sbn.scatterplot(x="mileage",y="price",data=newDataFrame)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
newDataFrame.sort_values("price",ascending=False).head(20)
# Out:
#        year   price  mileage  tax   mpg  engineSize
# 6199   2020  159999     1350  145  21.4         4.0
# 10044  2020  154998     3000  150  21.4         4.0
# 5      2011  149948     3000  570  21.4         6.2
# 8737   2019  140319      785  150  22.1         4.0
# 6386   2018  139995    13046  145  21.4         4.0
# 8      2019  139948    12000  145  21.4         4.0
# 9133   2019  139559     1000  145  22.1         4.0
# 8821   2020  138439     1000  145  22.1         4.0
# 5902   2018  135771    19000  145  21.4         4.0
# 7864   2018  135124    18234  150  21.4         4.0
# 8673   2019  134219     1000  145  24.8         4.0
# 6210   2019  129990     1000  145  24.8         4.0
# 4759   2019  126000      250  145  24.6         4.0
# 2647   2019  125796      637  145  24.8         4.0
# 6223   2019  124999     1500  145  31.7         4.0
# 4094   2019  124366      880  145  24.8         4.0
# 2629   2019  123846     2951  145  22.1         4.0
# ...

# %%
len(newDataFrame) * 0.01
# Out:
# 131.19

# %%
ninetyNine=newDataFrame.sort_values("price",ascending=False).iloc[131:]

# %%
ninetyNine.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.distplot(ninetyNine["price"])
# Out:
# C:\Users\Ramazan\AppData\Local\Temp\ipykernel_3992\4215087143.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(ninetyNine["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
newDataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
ninetyNine.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
newDataFrame[newDataFrame.year!=1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
newDataFrame=yuzdeDoksanDokuz

# %%
newDataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
newDataFrame=newDataFrame[newDataFrame.year!=1970]

# %%
newDataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
x=newDataFrame.drop("price",axis=1).values
y=newDataFrame["price"].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x = x_train , y = y_train, validation_data=(x_test,y_test),batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 3s 17ms/step - loss: 674377344.0000 - val_loss: 682880192.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 7ms/step - loss: 674335552.0000 - val_loss: 682803136.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 7ms/step - loss: 674174784.0000 - val_loss: 682498880.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 7ms/step - loss: 673627264.0000 - val_loss: 681573376.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 7ms/step - loss: 672080640.0000 - val_loss: 679106176.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 7ms/step - loss: 668301376.0000 - val_loss: 673456640.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 7ms/step - loss: 660238848.0000 - val_loss: 662129664.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 7ms/step - loss: 645030272.0000 - val_loss: 641736384.0000
# Epoch 9/300
# ...

# %%
lossData=pd.DataFrame(model.history.history)

# %%
lossData
# Out:
#             loss     val_loss
# 0    674377344.0  682880192.0
# 1    674335552.0  682803136.0
# 2    674174784.0  682498880.0
# 3    673627264.0  681573376.0
# 4    672080640.0  679106176.0
# ..           ...          ...
# 295   18841436.0   21026432.0
# 296   18843822.0   20929260.0
# 297   18837226.0   20934094.0
# 298   18825766.0   20963740.0
# 299   18832750.0   20983416.0
#
# [300 rows x 2 columns]

# %%
lossData.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
pred = model.predict(x_test)
# Out:
# 122/122 [==============================] - 1s 4ms/step

# %%
pred
# Out:
# array([[24111.3  ],
#        [21602.594],
#        [15009.776],
#        ...,
#        [20284.723],
#        [33628.098],
#        [24447.154]], dtype=float32)

# %%
mean_absolute_error(y_test,pred)
# Out:
# 3230.397811705619

# %%
newDataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test,pred)
plt.plot(y_test,y_test,"r-*")

# %%
newDataFrame.iloc[2]
# Out:
# year           2020.0
# price         65980.0
# mileage        3999.0
# tax             145.0
# mpg              28.0
# engineSize        4.0
# Name: 3191, dtype: float64

# %%
newCarSr=newDataFrame.drop("price",axis=1).iloc[2]

# %%
newCarSr
# Out:
# year          2020.0
# mileage       3999.0
# tax            145.0
# mpg             28.0
# engineSize       4.0
# Name: 3191, dtype: float64

# %%
newCarSr=scaler.transform(newCarSr.values.reshape(-1,5))

# %%
model.predict(newCarSr)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# array([[61753.645]], dtype=float32)

# %%
from tensorflow.keras.models import load_model

# %%
model.save("car_model.h5")

# %%
CallModel= load_model("car_model.h5")

# %%
CallModel.predict(newCarSr)
# Out:
# 1/1 [==============================] - 0s 152ms/step
# array([[61753.645]], dtype=float32)
